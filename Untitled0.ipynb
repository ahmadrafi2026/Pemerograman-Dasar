# %% [markdown]
# <a href="https://colab.research.google.com/github/ahmadrafi2026/Pemerograman-Dasar/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nama = "Ahmad"
umur = 19
jurusan = "RPE"
semester = 3
matakuliah = 'pemograman dasar'
status_lulus = False

print (nama)
print (umur)
print (jurusan)
print (semester)
print (matakuliah)
print (status_lulus)
# Out:
# Ahmad
# 19
# RPE
# 3
# pemograman dasar
# False
