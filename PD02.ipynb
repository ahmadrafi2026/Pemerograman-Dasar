# %% [markdown]
# <a href="https://colab.research.google.com/github/ahmadrafi2026/Pemerograman-Dasar/blob/main/PD02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
tegangan = 18
arus = 6
jenis_sel = "Monocrystalline"

print(tegangan)
print(arus)
print(jenis_sel)
# Out:
# 18
# 6
# Monocrystalline

# %%
jumlah_panel = 240
tegangan = 48.5
sedang_beroperasi = True
komponen = "Inverter"

print(jumlah_panel, type(jumlah_panel))
print(tegangan, type(tegangan))
print(sedang_beroperasi, type(sedang_beroperasi))
print(komponen, type(komponen))
# Out:
# 240 <class 'int'>
# 48.5 <class 'float'>
# True <class 'bool'>
# Inverter <class 'str'>

# %%
nama_unit = "PLTS Nunukan"
jumlah_panel = 240
tegangan_keluar = 48.5
sedang_beroperasi = True

print(nama_unit, type(nama_unit))
print(jumlah_panel, type(jumlah_panel))
print(tegangan_keluar, type(tegangan_keluar))
print(sedang_beroperasi, type(sedang_beroperasi))
# Out:
# PLTS Nunukan <class 'str'>
# 240 <class 'int'>
# 48.5 <class 'float'>
# True <class 'bool'>

# %%
tegangan_harian = [217.5, 219.0, 220.3, 218.7, 221.1, 216.9]

# (a) Cetak pembaca pertama dan terakhir
print(tegangan_harian[0])
print(tegangan_harian[-1])

# (b) Tambahkan pembaca baru
tegangan_harian.append(222.0)

#(c) Cetak jumlah total data
print(len(tegangan_harian))
# Out:
# 217.5
# 216.9
# 7

# %%
# Jawaban Latihan 5

motor = {
    "nama": "Motor Listrik",
    "daya_kW": 5,
    "tegangan_V": 220,
    "rpm": 1500
}

print(motor["nama"])

motor["rpm"] = 1800

print(motor)
# Out:
# Motor Listrik
# {'nama': 'Motor Listrik', 'daya_kW': 5, 'tegangan_V': 220, 'rpm': 1800}

# %%
# Jawaban Latihan 6

pembangkit = [
    {"nama": "Unit-1", "kapasitas_MW": 100, "status": "operasi"},
    {"nama": "Unit-2", "kapasitas_MW": 150, "status": "operasi"},
    {"nama": "Unit-3", "kapasitas_MW": 80, "status": "pemeliharaan"}
]

# Cetak nama unit kedua
print(pembangkit[1]["nama"])

# Ubah status salah satu unit
pembangkit[2]["status"] = "operasi"

# Tambahkan unit baru
pembangkit.append({
    "nama": "Unit-4",
    "kapasitas_MW": 200,
    "status": "operasi"
})

# Cetak seluruh data
print(pembangkit)
# Out:
# Unit-2
# [{'nama': 'Unit-1', 'kapasitas_MW': 100, 'status': 'operasi'}, {'nama': 'Unit-2', 'kapasitas_MW': 150, 'status': 'operasi'}, {'nama': 'Unit-3', 'kapasitas_MW': 80, 'status': 'operasi'}, {'nama': 'Unit-4', 'kapasitas_MW': 200, 'status': 'operasi'}]
